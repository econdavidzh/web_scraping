# %% [markdown]
# # Fundamentos de web scrapping:

# %%
import requests

response_la_republica = requests.get('https://www.larepublica.co/')
response_la_republica
# Out:
# <Response [200]>

# %% [markdown]
# Códigos de estado HTTP más comunes:
#
# Status code 200 – OK. \
# Status code 301 – Moved Permanently. \
# Status code 302 – Moved Temporarily. \
# Status code 403 – Forbidden \
# Status code 404 – Not Found \
# Status code 500 – Internal Server Error \
# Status code 503 ­– Service Unavailable \
#
# https://www.ionos.com/digitalguide/hosting/technical-matters/the-most-important-http-status-codes-at-a-glance/

# %% [markdown]
# HTML: define la estructura de la webpage
#
# **1. Para que sirve la etique script?**
# Sirve para controlar el comportamiento de un programa en especifico o para interactuar con el sistema operativo
#
# **2.Que son los metadatos?**
# Son elementos HTML que tienen como función describir la página web que los contiene. Estos son usados por los motores de búsqueda para hacer un análisis de dicho sitio web en cuanto a qué tipo de contenido se ofrece y cuál es la temática que allí se maneja
#
# 3.Cual es la etiqueta para colocar un sitio web dentro de otro?
# Etiqueta < iframe >
#
#
#
#
# < script> hace referencia a un código ejecutable \
# < meta> aporta información extra al documento (metadatos) \
# < iframe> colocar paginas externas dentro de la página actual

# %% [markdown]
# XML Xtensible markup lenguage. Sirvio para definir interfaces, es un lenguaje de nodos o etiquetas.
# Una técnica para extraer datos de allí es Xpath.
#
# Xpath es a HTML lo que las REGEX son a un texto.
# Es decir, Xpath es un lenguaje de patrones, expresiones que me permitirá extraer datos de un HTML. Puntualmente sirve para apuntar a partes de un documento XML.
#
# https://cheatography.com/davechild/cheat-sheets/regular-expressions/

# %%
# !pip install autopep8
# Out:
# ...
#      |████████████████████████████████| 45 kB 384 kB/s
# ...
#      |████████████████████████████████| 41 kB 531 kB/s
# ...

# %%
import lxml
import lxml.html as html
import autopep8

# %% [markdown]
# https://www.larepublica.co/
#
# titulos = $x('//a/*/text()').map(x=>x.wholeText)
#
#
# links = $x('//h2/a/@href').map(x=>x.value)

# %%
url = 'https://www.larepublica.co/'
titulos = '//a/text()'
links = "//a/@href"

# %%
def get_links():
  response = requests.get(url)
  home = response.content.decode('utf-8')
  parsed = html.fromstring(home)
  links_to_news = parsed.xpath(links)
  return list(set(links_to_news))

# %%
get_links()
# Out:
# ['https://www.larepublica.co/podcast/protagonistas-de-la-economia-colombiana',
#  'https://www.larepublica.co/finanzas/bolsas-repuntan-por-positivas-senales-de-evergrande-pero-con-temor-a-estanflacion-3239691',
#  'https://www.larepublica.co/comunidad-empresarial/pereira-se-esta-transformando/por-calidad-de-vida-e-incentivos-tributarios-eje-cafetero-se-vuelve-foco-de-inversiones-3213832',
#  'http://www.canalrcn.com',
#  'https://www.larepublica.co/videos',
#  'https://www.larepublica.co/inside/video/mauricio-hoyos-3237364',
#  'https://www.larepublica.co/nuevo-en-la-oficina',
#  'https://www.larepublica.co/analisis/carlos-ronderos-533356/corrupcion-3238752',
#  'https://www.larepublica.co/especiales/los-desafios-de-la-educacion',
#  'https://www.larepublica.co/indicadores-economicos/movimiento-accionario/fabricato',
#  'https://www.larepublica.co/empleo',
#  'https://www.larepublica.co/podcast/voces-para-educar',
#  'https://www.larepublica.co/globoeconomia',
# ...

# %%
def news():
  response = requests.get(url)
  home = response.content.decode('utf-8')
  parsed = html.fromstring(home)
  title = parsed.xpath(titulos)
  return title

# %%
news()
# Out:
# ['SUSCRÍBASE',
#  'La República',
#  'FINANZAS',
#  'ECONOMÍA',
#  'EMPRESAS',
#  'OCIO',
#  'GLOBOECONOMÍA',
#  'AGRONEGOCIOS',
#  'ANÁLISIS',
#  'ASUNTOS LEGALES',
#  'CAJA FUERTE',
#  'INDICADORES',
#  'INSIDE',
#  'Oficinas',
#  'Pensiones',
#  'Nutresa',
#  'Combustibles',
#  'Latin Lawyer',
#  'Fintech',
#  'Empleo',
#  'Laboral',
#  'Colpensiones',
#  'FINANZAS',
#  'ECONOMÍA',
#  'EMPRESAS',
#  'OCIO',
#  'GLOBOECONOMÍA',
#  'AGRONEGOCIOS',
#  'ANÁLISIS',
#  'ASUNTOS LEGALES',
#  'CAJA FUERTE',
#  'INDICADORES',
#  'INSIDE',
#  'Cerrar Sesión',
#  'SUSCRÍBASE',
#  '\n                                    ',
#  'INICIAR SESIÓN\n                                ',
#  'SUSCRÍBASE',
#  'FINANZAS',
#  'ECONOMÍA',
#  'EMPRESAS',
#  'OCIO',
#  'GLOBOECONOMÍA',
#  'AGRONEGOCIOS',
#  'ANÁLISIS',
#  'ASUNTOS LEGALES',
#  'CAJA FUERTE',
#  'CONSUMO',
#  'ALTA GERENCIA',
#  'FINANZAS PERSONALES',
#  'INFRAESTRUCTURA',
#  'INTERNET ECONOMY',
#  'RESPONSABILIDAD SOCIAL',
# ...

# %% [markdown]
# # Xpath:
#
# http://toscrape.com/ \
# http://quotes.toscrape.com/

# %% [markdown]
# $x('//h1/a/text()').map(x => x.wholeText)
# ['Quotes to Scrape']
# $x('//div/a/text()').map(x => x.wholeText)
# (30) ['change', 'deep-thoughts', 'thinking', 'world', 'abilities', 'choices', 'inspirational', 'life', 'live', 'miracle', 'miracles', 'aliteracy', 'books', 'classic', 'humor', 'be-yourself', 'inspirational', 'adulthood', 'success', 'value', 'life', 'love', 'edison', 'failure', 'inspirational', 'paraphrased', 'misattributed-eleanor-roosevelt', 'humor', 'obvious', 'simile']
# $x('//span/a/text()').map(x => x.wholeText)
# (20) ['(about)', '(about)', '(about)', '(about)', '(about)', '(about)', '(about)', '(about)', '(about)', '(about)', 'love', 'inspirational', 'life', 'humor', 'books', 'reading', 'friendship', 'friends', 'truth', 'simile']
# $x('//span/@class')
# (21) [class, class, class, class, class, class, class, class, class, class, class, class, class, class, class, class, class, class, class, class, class]
# $x('//li/@class')
# [class]
# $x('/html/body/div/div[1]')
# [div.row.header-box]
# $x('/html/body/div/div[2]')
# [div.row]
# $x('/html/body/div/div[last()]')
# [div.row]
# $x('//span[@class]')
# (21) [span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.sh-red]
# $x('//span[@class="text"]/text()').map(x => x.wholeText)
# (10) ['“The world as we have created it is a process of o…cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', '“There are only two ways to live your life. One is… The other is as though everything is a miracle.”', '“The person, be it gentleman or lady, who has not …ure in a good novel, must be intolerably stupid.”', "“Imperfection is beauty, madness is genius and it'…be absolutely ridiculous than absolutely boring.”", '“Try not to become a man of success. Rather become a man of value.”', '“It is better to be hated for what you are than to be loved for what you are not.”', "“I have not failed. I've just found 10,000 ways that won't work.”", "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”", '“A day without sunshine is like, you know, night.”']
# $x('//span[@class!="text"]')
# (11) [span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.sh-red]
# $x('/html/body/div/div[position()>1]')
# [div.row]
# $x('//span[@class="text" or @class="tag-item"]')
# (20) [span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.text, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item, span.tag-item]
# $x('//span[not(@class)]')
# (11) [span, span, span, span, span, span, span, span, span, span, span]

# %% [markdown]
# #Wilcards = comodines
# Ejemplos
#
# $x('/') <- Trae todo el documento porque representa la raíz de nuestro el html
# $x('/*') <- * después de / pide que traiga todos los nodos que están debajo de / (* es el primer wildcard)
# $x('/html/*') <- Trae todos los nodos que están inmediatamente después de html
# $x('//*') <- // es la expresión para saltar todos los niveles y con el * en todas las direcciones. Trae todos los nodos y todos los atributos de estos nodos.
# $x('//span[@class="text]/@*') <- Trae todos los span, que tengan como clase “text”, con @* trae todos los atributos. Dicho de otra forma, trae todos los atributos de todos los nodos de tipo span de clase “text”.
# $x('/html/body//div/@*') <- Todos los atributos (usando @*) de todos los div (usando //div) que están después de body
# $x('//span[@class="text" and @itemprop="text"]/node()') <- Trae todos los spam que sean de clase “text” que tengan un atributo @itemprop “text” y de ahí (usando node()) traer todo lo que esté dentro de los spam que cumplen las condiciones
#
# node() a diferencia de * trae no solamente los nodos, sino también todo el contenido

# %% [markdown]
# $x('/html/*')
# (2) [head, body]
# $x('//*')
# (151) [html, head, meta, title, link, link, body, div.container, div.row.header-box, div.col-md-8, h1, a, div.col-md-4, p, a, div.row, div.col-md-8, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, a.tag, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, div.quote, span.text, span, small.author, a, div.tags, meta.keywords, a.tag, a.tag, a.tag, a.tag, div.quote, …]
# $x('//span[@class="text"]/@*')
# (20) [class, itemprop, class, itemprop, class, itemprop, class, itemprop, class, itemprop, class, itemprop, class, itemprop, class, itemprop, class, itemprop, class, itemprop]
# $x('/html/body//div/@*')
# (48) [class, class, class, class, class, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, itemscope, itemtype, class, class, class]
#
# $x('//span[@class="text" and @itemprop="text"]/node()')
# (10) [text, text, text, text, text, text, text, text, text, text]

# %% [markdown]
# # in text search xPath:

# %% [markdown]
# $x('//small[@class="author" and starts-with(.,"A")]/text()').map(x=>x.wholeText)
# (4) ['Albert Einstein', 'Albert Einstein', 'Albert Einstein', 'André Gide']
#
# $x('//small[@class="author" and contains(.,"Ro")]/text()').map(x=>x.wholeText)
# (2) ['J.K. Rowling', 'Eleanor Roosevelt']

# %% [markdown]
# # xPath Axes:

# %% [markdown]
# $x('/html/body/div/descendant::div')
# (26) [div.row.header-box, div.col-md-8, div.col-md-4, div.row, div.col-md-8, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.col-md-4.tags-box]
# $x('/html/body/div/self::div')
# [div.container]
# $x('/html/body/div/.')
# [div.container]
# $x('/html/body/div/child::div')
# (2) [div.row.header-box, div.row]
# $x('/html/body/div/descendant-or-self::div')
# (27) [div.container, div.row.header-box, div.col-md-8, div.col-md-4, div.row, div.col-md-8, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.quote, div.tags, div.col-md-4.tags-box]

# %% [markdown]
# http://books.toscrape.com/

# %% [markdown]
# $x('//article[@class="product_pod"]/h3/a/@title')
# (20) [title, title, title, title, title, title, title, title, title, title, title, title, title, title, title, title, title, title, title, title]
# $x('//article[@class="product_pod"]/h3/a/@title').map(x=>x.wholeText)
# (20) [undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined, undefined]
# $x('//article[@class="product_pod"]/h3/a/text()').map(x=>x.wholeText)
# (20) ['A Light in the ...', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History ...', 'The Requiem Red', 'The Dirty Little Secrets ...', 'The Coming Woman: A ...', 'The Boys in the ...', 'The Black Maria', 'Starving Hearts (Triangular Trade ...', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little ...", 'Rip it Up and ...', 'Our Band Could Be ...', 'Olio', 'Mesaerion: The Best Science ...', 'Libertarianism for Beginners', "It's Only the Himalayas"]
# $x('//article[@class="product_pod"]/div[@Class="product_price"]/p[@Class="price_color"]/text()').map(x=>x.wholeText)
# (20) ['£51.77', '£53.74', '£50.10', '£47.82', '£54.23', '£22.65', '£33.34', '£17.93', '£22.60', '£52.15', '£13.99', '£20.66', '£17.46', '£52.29', '£35.02', '£57.25', '£23.88', '£37.59', '£51.33', '£45.17']

# %% [markdown]
# The 14 Best Data Scraping Tools and Web Scraping Tools
#
# https://www.scraperapi.com/blog/the-10-best-web-scraping-tools/
#
# Xpath cheatsheet
#
# https://devhints.io/xpath
